# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("Desktop\ANALISIS\BASES DE DATOS PARA PRACTICAR\PRUEBA SABER 11\Saber_11__2019-2.csv", low_memory=False)

# %%
w=3
for i in df['FAMI_TRABAJOLABORPADRE'][w]:
    if i == ',':
        w = w + 1
    else:
        continue
print(w)
# Out:
# 3

# %%
df['FAMI_TRABAJOLABORPADRE'] = df['FAMI_TRABAJOLABORPADRE'].replace({',': ''}, regex=True)
#data["Real time"] = data["Real time"].replace({'0m':''}, regex=True)
df['FAMI_TRABAJOLABORPADRE']
# Out:
# 0                                                 No aplica
# 1         Trabaja por cuenta propia (por ejemplo plomero...
# 2              Es vendedor o trabaja en atención al público
# 3                                                 No aplica
# 4                  Trabaja en el hogar no trabaja o estudia
#                                 ...
# 546207    Trabaja por cuenta propia (por ejemplo plomero...
# 546208                                              No sabe
# 546209    Trabaja como profesional (por ejemplo médico a...
# 546210    Trabaja como personal de limpieza mantenimient...
# 546211                                              No sabe
# Name: FAMI_TRABAJOLABORPADRE, Length: 546212, dtype: object

# %%
df['FAMI_TRABAJOLABORPADRE'], df['FAMI_TRABAJOLABORMADRE']
# Out:
# (0                                                 No aplica
#  1         Trabaja por cuenta propia (por ejemplo plomero...
#  2              Es vendedor o trabaja en atención al público
#  3                                                 No aplica
#  4                  Trabaja en el hogar no trabaja o estudia
#                                  ...
#  546207    Trabaja por cuenta propia (por ejemplo plomero...
#  546208                                              No sabe
#  546209    Trabaja como profesional (por ejemplo médico a...
#  546210    Trabaja como personal de limpieza mantenimient...
#  546211                                              No sabe
#  Name: FAMI_TRABAJOLABORPADRE, Length: 546212, dtype: object,
#  0                 Trabaja en el hogar, no trabaja o estudia
#  1         Es dueño de un negocio pequeño (tiene pocos em...
#  2              Es vendedor o trabaja en atención al público
#  3         Es dueño de un negocio pequeño (tiene pocos em...
# ...

# %%
df.head()
# Out:
#   ESTU_TIPODOCUMENTO ESTU_NACIONALIDAD ESTU_GENERO    ESTU_FECHANACIMIENTO  \
# 0                 TI          COLOMBIA           M  02/18/2002 12:00:00 AM
# 1                 TI          COLOMBIA           M  06/28/2003 12:00:00 AM
# 2                 TI          COLOMBIA           M  06/02/2001 12:00:00 AM
# 3                 TI          COLOMBIA           M  04/26/2002 12:00:00 AM
# 4                 TI          COLOMBIA           M  02/05/2002 12:00:00 AM
#
#    PERIODO  ESTU_CONSECUTIVO ESTU_ESTUDIANTE ESTU_TIENEETNIA ESTU_PAIS_RESIDE  \
# 0    20194  SB11201940031558      ESTUDIANTE              No         COLOMBIA
# 1    20194  SB11201940303339      ESTUDIANTE              No         COLOMBIA
# 2    20194  SB11201940255017      ESTUDIANTE              No         COLOMBIA
# 3    20194  SB11201940154799      ESTUDIANTE              Si         COLOMBIA
# 4    20194  SB11201940280831      ESTUDIANTE              No         COLOMBIA
#
# ...

# %%
df.describe()
# Out:
#         PERIODO  COLE_CODIGO_ICFES  COLE_COD_DANE_ESTABLECIMIENTO  \
# count  546212.0      546212.000000                   5.462120e+05
# mean    20194.0      197397.840712                   2.038424e+11
# std         0.0      229636.502160                   9.221826e+10
# min     20194.0          75.000000                   1.050010e+11
# 25%     20194.0       45732.000000                   1.170500e+11
# 50%     20194.0      113076.000000                   1.732085e+11
# 75%     20194.0      194779.000000                   3.050010e+11
# max     20194.0      728303.000000                   8.548740e+11
#
#        COLE_COD_DANE_SEDE  COLE_COD_MCPIO_UBICACION  COLE_COD_DEPTO_UBICACION  \
# count        5.462120e+05             546212.000000             546212.000000
# mean         2.044208e+11              32755.704584                 32.516563
# std          9.302404e+10              26364.009436                 26.340054
# ...

# %%
df.columns.values
# Out:
# array(['ESTU_TIPODOCUMENTO', 'ESTU_NACIONALIDAD', 'ESTU_GENERO',
#        'ESTU_FECHANACIMIENTO', 'PERIODO', 'ESTU_CONSECUTIVO',
#        'ESTU_ESTUDIANTE', 'ESTU_TIENEETNIA', 'ESTU_PAIS_RESIDE',
#        'ESTU_ETNIA', 'ESTU_DEPTO_RESIDE', 'ESTU_COD_RESIDE_DEPTO',
#        'ESTU_MCPIO_RESIDE', 'ESTU_COD_RESIDE_MCPIO',
#        'FAMI_ESTRATOVIVIENDA', 'FAMI_PERSONASHOGAR', 'FAMI_CUARTOSHOGAR',
#        'FAMI_EDUCACIONPADRE', 'FAMI_EDUCACIONMADRE',
#        'FAMI_TRABAJOLABORPADRE', 'FAMI_TRABAJOLABORMADRE',
#        'FAMI_TIENEINTERNET', 'FAMI_TIENESERVICIOTV',
#        'FAMI_TIENECOMPUTADOR', 'FAMI_TIENELAVADORA',
#        'FAMI_TIENEHORNOMICROOGAS', 'FAMI_TIENEAUTOMOVIL',
#        'FAMI_TIENEMOTOCICLETA', 'FAMI_TIENECONSOLAVIDEOJUEGOS',
#        'FAMI_NUMLIBROS', 'FAMI_COMELECHEDERIVADOS',
#        'FAMI_COMECARNEPESCADOHUEVO', 'FAMI_COMECEREALFRUTOSLEGUMBRE',
#        'FAMI_SITUACIONECONOMICA', 'ESTU_DEDICACIONLECTURADIARIA',
# ...

# %%
w = 0
for i in  df['ESTU_NACIONALIDAD']:
    if i != 'COLOMBIA':
        w = w+1

print('CANTIDAD DE ESTUDAINTES EXTRANJEROS:', w)
# Out:
# CANTIDAD DE ESTUDAINTES EXTRANJEROS: 1294

# %%
w = 0
for i in  df['ESTU_NACIONALIDAD']:
    if i == 'COLOMBIA':
        w = w+1

print('CANTIDAD DE ESTUDIANTES COLOMBIANOS:', w)
# Out:
# CANTIDAD DE ESTUDIANTES COLOMBIANOS: 544918

# %%
w = 0
for i in  df['ESTU_GENERO']:
    if i != 'M':
        w = w+1

print('CANTIDAD DE ESTUDAINTES MUJER:', w)
# Out:
# CANTIDAD DE ESTUDAINTES MUJER: 296115

# %%
w = 0
for i in  df['ESTU_GENERO']:
    if i != 'F':
        w = w+1

print('CANTIDAD DE ESTUDAINTES HOMBRE:', w)
# Out:
# CANTIDAD DE ESTUDAINTES HOMBRE: 250218

# %%
df.groupby('ESTU_GENERO').count()
# Out:
#              ESTU_TIPODOCUMENTO  ESTU_NACIONALIDAD  ESTU_FECHANACIMIENTO  \
# ESTU_GENERO
# -                           121                121                   121
# F                        295994             295994                295994
# M                        250097             250097                250097
#
#              PERIODO  ESTU_CONSECUTIVO  ESTU_ESTUDIANTE  ESTU_TIENEETNIA  \
# ESTU_GENERO
# -                121               121              121              121
# F             295994            295994           295994           295994
# M             250097            250097           250097           250097
#
#              ESTU_PAIS_RESIDE  ESTU_ETNIA  ESTU_DEPTO_RESIDE  ...  \
# ESTU_GENERO                                                   ...
# -                         121         121                118  ...
# F                      295994      295994             295803  ...
# M                      250097      250097             249914  ...
#
# ...

# %%
df.groupby('ESTU_NACIONALIDAD').count().sort_values('ESTU_TIPODOCUMENTO', ascending = False)['ESTU_TIPODOCUMENTO']
# Out:
# ESTU_NACIONALIDAD
# COLOMBIA                  544918
# VENEZUELA                   1109
# ESTADOS UNIDOS                52
# ESPAÑA                        33
# ECUADOR                       26
# PERÚ                           7
# CUBA                           6
# MÉXICO                         6
# BOLIVIA                        5
# BRASIL                         5
# ITALIA                         5
# ARGENTINA                      4
# COSTA RICA                     4
# FRANCIA                        3
# EL SALVADOR                    3
# CHILE                          3
# COMORAS                        3
# CHINA                          2
# PAÍSES BAJOS - HOLANDA         2
# REPÚBLICA DOMINICANA           2
# COREA DEL NORTE                2
# TAIWAN                         1
# REINO UNIDO                    1
# PANAMÁ                         1
# VANUATU                        1
# AFGANISTÁN                     1
# DINAMARCA                      1
# ALBANIA                        1
# ...

# %%
df.groupby('ESTU_MCPIO_RESIDE').count().sort_values('ESTU_TIPODOCUMENTO', ascending = False)['ESTU_TIPODOCUMENTO']
# Out:
# ESTU_MCPIO_RESIDE
# BOGOTÁ D.C.            83600
# MEDELLÍN               28222
# BARRANQUILLA           17177
# CALI                   16542
# CARTAGENA DE INDIAS    13535
#                        ...
# BUSBANZÁ                   7
# PACOA                      5
# MORICHAL                   4
# JORDÁN                     4
# BELÉN DE BAJIRÁ            1
# Name: ESTU_TIPODOCUMENTO, Length: 1031, dtype: int64

# %%
df.groupby('FAMI_ESTRATOVIVIENDA').count().sort_values('ESTU_TIPODOCUMENTO', ascending = False)['ESTU_TIPODOCUMENTO']
# Out:
# FAMI_ESTRATOVIVIENDA
# Estrato 2      188314
# Estrato 1      159977
# Estrato 3      108692
# -               34481
# Estrato 4       25810
# Sin Estrato     17177
# Estrato 5        8024
# Estrato 6        3711
# Name: ESTU_TIPODOCUMENTO, dtype: int64

# %%
df.groupby('FAMI_EDUCACIONPADRE').count().sort_values('ESTU_TIPODOCUMENTO', ascending = False)['ESTU_TIPODOCUMENTO']
# Out:
# FAMI_EDUCACIONPADRE
# Secundaria (Bachillerato) completa      117488
# Primaria incompleta                     101387
# Secundaria (Bachillerato) incompleta     71295
# Primaria completa                        54141
# Educación profesional completa           46404
# Técnica o tecnológica completa           35367
# No sabe                                  32104
# -                                        22235
# Ninguno                                  20106
# Técnica o tecnológica incompleta         10957
# Educación profesional incompleta         10150
# Postgrado                                 9437
# No Aplica                                 6849
# Name: ESTU_TIPODOCUMENTO, dtype: int64

# %%
df.groupby('FAMI_EDUCACIONMADRE').count().sort_values('ESTU_TIPODOCUMENTO', ascending = False)['ESTU_TIPODOCUMENTO']
# Out:
# FAMI_EDUCACIONMADRE
# Secundaria (Bachillerato) completa      136286
# Primaria incompleta                      80062
# Secundaria (Bachillerato) incompleta     76353
# Educación profesional completa           54474
# Primaria completa                        53441
# Técnica o tecnológica completa           52949
# Técnica o tecnológica incompleta         15973
# Ninguno                                  12762
# Educación profesional incompleta         12384
# Postgrado                                10805
# -                                         9408
# No sabe                                   9275
# No Aplica                                 1081
# Name: ESTU_TIPODOCUMENTO, dtype: int64

# %%
df.groupby('FAMI_TRABAJOLABORPADRE').count().sort_values('ESTU_TIPODOCUMENTO', ascending = False)['ESTU_TIPODOCUMENTO']
# Out:
# FAMI_TRABAJOLABORPADRE
# Es agricultor pesquero o jornalero                                                                   78187
# Trabaja por cuenta propia (por ejemplo plomero electricista)                                         60949
# Es operario de máquinas o conduce vehículos (taxita chofer)                                          56948
# No aplica                                                                                            49029
# No sabe                                                                                              44249
# Es dueño de un negocio pequeño (tiene pocos empleados o no tiene por ejemplo tienda papelería etc    44247
# Trabaja como profesional (por ejemplo médico abogado ingeniero)                                      41203
# Trabaja como personal de limpieza mantenimiento seguridad o construcción                             39965
# ...

# %%
df.groupby('FAMI_TRABAJOLABORMADRE').count().sort_values('ESTU_TIPODOCUMENTO', ascending = False)['ESTU_TIPODOCUMENTO']
# Out:
# FAMI_TRABAJOLABORMADRE
# Trabaja en el hogar, no trabaja o estudia                                                               213377
# Es dueño de un negocio pequeño (tiene pocos empleados o no tiene, por ejemplo tienda, papelería, etc     48129
# Trabaja como personal de limpieza, mantenimiento, seguridad o construcción                               46890
# Tiene un trabajo de tipo auxiliar administrativo (por ejemplo, secretario o asistente)                   44407
# Trabaja como profesional (por ejemplo médico, abogado, ingeniero)                                        41939
# Es vendedor o trabaja en atención al público                                                             40370
# No aplica                                                                                                27451
# Es agricultor, pesquero o jornalero                                                                      17017
# ...

# %%
df.groupby('FAMI_SITUACIONECONOMICA').count().sort_values('ESTU_TIPODOCUMENTO', ascending = False)['ESTU_TIPODOCUMENTO']*100/544918
# Out:
# FAMI_SITUACIONECONOMICA
# Igual    59.187621
# Mejor    24.533967
# Peor     13.235569
# -         1.764669
# Name: ESTU_TIPODOCUMENTO, dtype: float64

# %%
df.groupby('FAMI_TIENECONSOLAVIDEOJUEGOS').count().sort_values('ESTU_TIPODOCUMENTO', ascending = False)['ESTU_TIPODOCUMENTO']
# Out:
# FAMI_TIENECONSOLAVIDEOJUEGOS
# No    410475
# Si    117642
# -      10370
# Name: ESTU_TIPODOCUMENTO, dtype: int64

# %%
df.groupby('ESTU_TIPODOCUMENTO').count().sort_values('ESTU_ESTADOINVESTIGACION', ascending = False)['ESTU_ESTADOINVESTIGACION']
# Out:
# ESTU_TIPODOCUMENTO
# TI     445780
# CC      91921
# CR       6123
# CE       1225
# NES       822
# PEP       235
# PE         91
# PC          6
# RC          5
# CCB         4
# Name: ESTU_ESTADOINVESTIGACION, dtype: int64

# %%
for i in df.columns.values:
    ya = df.groupby(i).count().sort_values('ESTU_ESTADOINVESTIGACION', ascending = False)
    print(ya)
# Out:
#                     ESTU_NACIONALIDAD  ESTU_GENERO  ESTU_FECHANACIMIENTO  \
# ESTU_TIPODOCUMENTO
# TI                             445780       445780                445780
# CC                              91921        91921                 91921
# CR                               6123         6123                  6123
# CE                               1225         1225                  1225
# NES                               822          822                   822
# PEP                               235          235                   235
# PE                                 91           91                    91
# PC                                  6            6                     6
# RC                                  5            5                     5
# CCB                                 4            4                     4
#
#                     PERIODO  ESTU_CONSECUTIVO  ESTU_ESTUDIANTE  \
# ESTU_TIPODOCUMENTO
# ...

# %%
df_1 = df.groupby('FAMI_SITUACIONECONOMICA').count().sort_values('ESTU_TIPODOCUMENTO', ascending = False)['ESTU_TIPODOCUMENTO']
df_2 = df.groupby('FAMI_ESTRATOVIVIENDA').count().sort_values('ESTU_TIPODOCUMENTO', ascending = False)['ESTU_TIPODOCUMENTO']
#plt.bar(df_1.index, df_1)
#plt.bar(df_2.index, df_2)
df_1.loc[df_1 < 100000].plot(kind = 'bar', stacked=True);
#df_2.plot(kind = 'bar', stacked=True);

# %%
g = df.loc[df['FAMI_SITUACIONECONOMICA'] == 'Peor']['FAMI_ESTRATOVIVIENDA']
g
# Out:
# 0         Estrato 3
# 10        Estrato 1
# 19                -
# 30        Estrato 1
# 34        Estrato 3
#             ...
# 546176    Estrato 1
# 546180    Estrato 1
# 546188    Estrato 2
# 546189    Estrato 1
# 546193    Estrato 3
# Name: FAMI_ESTRATOVIVIENDA, Length: 72123, dtype: object

# %%
#df.loc[df.groupby('FAMI_SITUACIONECONOMICA').count()['ESTU_FECHANACIMIENTO'] < 500000]
h = df.groupby('FAMI_SITUACIONECONOMICA').count()['ESTU_FECHANACIMIENTO']
h1 = h.loc[h > 10000 ]
h1
# Out:
# FAMI_SITUACIONECONOMICA
# Igual    322524
# Mejor    133690
# Peor      72123
# Name: ESTU_FECHANACIMIENTO, dtype: int64

# %%
h1.plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='FAMI_SITUACIONECONOMICA'>

# %%
fil1 = df[df['FAMI_SITUACIONECONOMICA'] == 'Peor']
fil2 = fil1[fil1['FAMI_ESTRATOVIVIENDA'] == 'Estrato 6']
plt.bar(fil2['ESTU_GENERO'], fil2['ESTU_GENERO'].index)
# Out:
# <BarContainer object of 399 artists>

# %%
hom = df[df['ESTU_GENERO'] == 'M']#CANTIDAD TOTAL DE HOMNRES: 250097
punt1 = hom[hom['PUNT_INGLES'] > 50]
to1 = punt1.count()['ESTU_NACIONALIDAD']*100/295994 
muj = df[df['ESTU_GENERO'] == 'F']#CANTIDAD TOTAL DE HOMNRES: 295994 
punt2 = muj[muj['PUNT_INGLES'] > 50]
to2 = punt2.count()['ESTU_NACIONALIDAD']*100/295994
plt.pie([to1, to2], labels = ['Hom', 'Muj']);

# %%
# Out:
# 14.764488469360865

# %%
df[df['ESTU_GENERO'] == 'F'].count()
# Out:
# ESTU_TIPODOCUMENTO          295994
# ESTU_NACIONALIDAD           295994
# ESTU_GENERO                 295994
# ESTU_FECHANACIMIENTO        295994
# PERIODO                     295994
#                              ...
# ESTU_INSE_INDIVIDUAL        295993
# ESTU_NSE_INDIVIDUAL         287585
# ESTU_NSE_ESTABLECIMIENTO    295988
# ESTU_ESTADOINVESTIGACION    295994
# ESTU_GENERACION-E           295994
# Length: 82, dtype: int64

# %%
df = pd.read_csv("Desktop\ANALISIS\BASES DE DATOS PARA PRACTICAR\PRUEBA SABER 11\Saber_11__2020-2.csv", low_memory=False)

# %%
df.columns.values
# Out:
# array(['ESTU_TIPODOCUMENTO', 'ESTU_NACIONALIDAD', 'ESTU_GENERO',
#        'ESTU_FECHANACIMIENTO', 'PERIODO', 'ESTU_CONSECUTIVO',
#        'ESTU_ESTUDIANTE', 'ESTU_PAIS_RESIDE', 'ESTU_TIENEETNIA',
#        'ESTU_DEPTO_RESIDE', 'ESTU_COD_RESIDE_DEPTO', 'ESTU_MCPIO_RESIDE',
#        'ESTU_COD_RESIDE_MCPIO', 'FAMI_ESTRATOVIVIENDA',
#        'FAMI_PERSONASHOGAR', 'FAMI_CUARTOSHOGAR', 'FAMI_EDUCACIONPADRE',
#        'FAMI_EDUCACIONMADRE', 'FAMI_TRABAJOLABORPADRE',
#        'FAMI_TRABAJOLABORMADRE', 'FAMI_TIENEINTERNET',
#        'FAMI_TIENESERVICIOTV', 'FAMI_TIENECOMPUTADOR',
#        'FAMI_TIENELAVADORA', 'FAMI_TIENEHORNOMICROOGAS',
#        'FAMI_TIENEAUTOMOVIL', 'FAMI_TIENEMOTOCICLETA',
#        'FAMI_TIENECONSOLAVIDEOJUEGOS', 'FAMI_NUMLIBROS',
#        'FAMI_COMELECHEDERIVADOS', 'FAMI_COMECARNEPESCADOHUEVO',
#        'FAMI_COMECEREALFRUTOSLEGUMBRE', 'FAMI_SITUACIONECONOMICA',
#        'ESTU_DEDICACIONLECTURADIARIA', 'ESTU_DEDICACIONINTERNET',
# ...

# %%
plt.bar(df['PUNT_SOCIALES_CIUDADANAS'].mean(), df['PUNT_GLOBAL'].mean(), 0.8)
plt.bar(df['PUNT_LECTURA_CRITICA'].mean(), df['PUNT_GLOBAL'].mean(), 0.8)
plt.bar(df['PUNT_MATEMATICAS'].mean(), df['PUNT_GLOBAL'].mean(), 0.8)
plt.bar(df['PUNT_C_NATURALES'].mean(), df['PUNT_GLOBAL'].mean(), 0.8)
plt.bar(df['PUNT_INGLES'].mean(), df['PUNT_GLOBAL'].mean(), 0.8)
plt.bar(df['PUNT_SOCIALES_CIUDADANAS'].mean(), df['PUNT_GLOBAL'].mean(), 0.8)

# %%
df['PUNT_GLOBAL'].mean()
# Out:
# 248.34710183967422

# %%
a = [df['PUNT_SOCIALES_CIUDADANAS'].mean(), df['PUNT_LECTURA_CRITICA'].mean(), df['PUNT_MATEMATICAS'].mean(), df['PUNT_C_NATURALES'].mean(), df['PUNT_INGLES'].mean()]
b = df['PUNT_GLOBAL'].mean()
plt.bar(a, b, 0.8)
# Out:
# <BarContainer object of 5 artists>

# %%
np.mean([1, 2, 3, 4, 5])
# Out:
# 3.0

# %%
estrato = df.groupby('FAMI_ESTRATOVIVIENDA').mean().sort_values('PUNT_GLOBAL', ascending = False)['PUNT_GLOBAL']
estrato.plot(kind = 'bar')
# Out:
# <AxesSubplot:xlabel='FAMI_ESTRATOVIVIENDA'>

# %%
df.dtypes
# Out:
# ESTU_TIPODOCUMENTO           object
# ESTU_NACIONALIDAD            object
# ESTU_GENERO                  object
# ESTU_FECHANACIMIENTO         object
# PERIODO                       int64
#                              ...
# ESTU_INSE_INDIVIDUAL        float64
# ESTU_NSE_INDIVIDUAL         float64
# ESTU_NSE_ESTABLECIMIENTO    float64
# ESTU_ESTADOINVESTIGACION     object
# ESTU_GENERACION-E            object
# Length: 81, dtype: object
